# %%
# import data from csv
import csv
from math import floor

# %%
# let´s create a list for each column of the csv file
ages = []
sexes = []
bmis = []
num_children = []
smokers = []
regions = []
insurance_charges = []

# %%
def load_data(lst, file_name, col_name):
    # open the csv file
    with open(file_name) as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            lst.append(row[col_name])
    return lst

# %%
# Load the data into lists
load_data(ages, 'insurance.csv', 'age')
load_data(sexes, 'insurance.csv', 'sex')
load_data(bmis, 'insurance.csv', 'bmi')
load_data(num_children, 'insurance.csv', 'children')
load_data(smokers, 'insurance.csv', 'smoker')
load_data(regions, 'insurance.csv', 'region')
load_data(insurance_charges, 'insurance.csv', 'charges')
# Out:
# ['16884.924',
#  '1725.5523',
#  '4449.462',
#  '21984.47061',
#  '3866.8552',
#  '3756.6216',
#  '8240.5896',
#  '7281.5056',
#  '6406.4107',
#  '28923.13692',
#  '2721.3208',
#  '27808.7251',
#  '1826.843',
#  '11090.7178',
#  '39611.7577',
#  '1837.237',
#  '10797.3362',
#  '2395.17155',
#  '10602.385',
#  '36837.467',
#  '13228.84695',
#  '4149.736',
#  '1137.011',
#  '37701.8768',
#  '6203.90175',
#  '14001.1338',
#  '14451.83515',
#  '12268.63225',
#  '2775.19215',
#  '38711',
#  '35585.576',
#  '2198.18985',
#  '4687.797',
#  '13770.0979',
#  '51194.55914',
#  '1625.43375',
#  '15612.19335',
#  '2302.3',
#  '39774.2763',
#  '48173.361',
#  '3046.062',
#  '4949.7587',
#  '6272.4772',
#  '6313.759',
#  '6079.6715',
#  '20630.28351',
#  '3393.35635',
#  '3556.9223',
#  '12629.8967',
#  '38709.176',
#  '2211.13075',
#  '3579.8287',
#  '23568.272',
#  '37742.5757',
#  '8059.6791',
#  '47496.49445',
#  '13607.36875',
#  '34303.1672',
#  '23244.7902',
#  '5989.52365',
# ...

# %%
print(len(ages), len(insurance_charges), len(sexes))
# Out:
# 1338 1338 1338

# %%
# convert to correct types
ages = [int(age) for age in ages]
num_children = [int(children) for children in num_children]
insurance_charges = [float(charge) for charge in insurance_charges]
bmis = [float(bmi) for bmi in bmis]

# %%
class MedInfo():
    def __init__(self, ages, sexes, bmis, num_children, smokers, regions, insurance_charges):
        self.ages = ages
        self.sexes = sexes
        self.bmis = bmis
        self.num_children = num_children
        self.smokers = smokers
        self.regions = regions
        self.insurance_charges =insurance_charges

      
    def avg_age(self):
        total_ages = 0
                
        for age in self.ages:
            total_ages += age
        return f"The average of all patients is {total_ages/len(self.ages): .0f}"

    def unique_regions(self):
        unique_regions = set(self.regions)
        return list(unique_regions)

    def sex_cost(self):
        men = 0
        women = 0
        total_man = 0
        total_woman = 0

        for i in range(len(self.sexes)):
            if self.sexes[i] == 'male':
                men += self.insurance_charges[i]
                total_man += 1
            else:
                women += self.insurance_charges[i]
                total_woman += 1
        
        return f"The average of insurance for men {men/total_man: .0f} dollars while for women {women/total_woman: .0f} dollars"

    def cost_region(self):
        region_ins = {'northeast': 0, 'southeast': 0, 'southwest': 0, 'northwest': 0}
        region_amount = {'northeast': 0, 'southeast': 0, 'southwest': 0, 'northwest': 0}
        region_avg_cost = {'northeast': 0, 'southeast': 0, 'southwest': 0, 'northwest': 0}

        for i in range(len(self.regions)):
            for k in region_ins.keys():
                if self.regions[i] == k:
                    region_ins[k] += 1
                    region_amount[k] = self.insurance_charges[i]

        for k in region_avg_cost.keys():
            region_avg_cost[k] = region_amount[k] / region_ins[k]
            print(f"The {k} region with {region_ins[k]} registered patients have an average insurance cost of {region_avg_cost[k]: 2f} dollars\n")
        return region_ins,region_amount,region_avg_cost

# %%
patient_info = MedInfo(ages, sexes, bmis, num_children, smokers, regions, insurance_charges)
print(patient_info.unique_regions())
print(patient_info.avg_age())
print(patient_info.sex_cost())
print(patient_info.cost_region())
# Out:
# ['northwest', 'southeast', 'southwest', 'northeast']
# The average of all patients is  39
# The average of insurance for men  13957 dollars while for women  12570 dollars
# The northeast region with 324 registered patients have an average insurance cost of  6.808583 dollars
#
# The southeast region with 364 registered patients have an average insurance cost of  4.477565 dollars
#
# The southwest region with 325 registered patients have an average insurance cost of  6.178292 dollars
#
# The northwest region with 325 registered patients have an average insurance cost of  89.665724 dollars
#
# ({'northeast': 324, 'southeast': 364, 'southwest': 325, 'northwest': 325}, {'northeast': 2205.9808, 'southeast': 1629.8335, 'southwest': 2007.945, 'northwest': 29141.3603}, {'northeast': 6.808582716049382, 'southeast': 4.477564560439561, 'southwest': 6.178292307692307, 'northwest': 89.665724})
